# %%
                       # Virtual Internship Program by AINE AI
                       # Data Manipulation and Visualization using Python

# %%
# TO DO: Import pandas library as an alias name (nickname) pd
# Syntax hint: import libraryname as aliasname
import pandas as pd

# %%
# Getting data from local location in our system.
brics = pd.read_csv(r'C:\Users\dkk\AINE AI - Intern\project-6-Data-Manipulation-and-Visualization\brics.csv')  # Change this path as per your folder arrangements.

# Make sure the folder names are seperated by either a forward slash (/)or two backward slashes (\\) in the above code.

brics
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
# Data type of any variable can be seen using the function type()

print(type(5))
print(type('a text'))
print(type(True))
print(type(brics))         # datatype of the dataframe created above
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'pandas.core.frame.DataFrame'>

# %%
'''
The info() function is used to print a concise summary of a DataFrame. 
This method prints information about a DataFrame including the index dtype and column dtypes, 
non-null values and memory usage.
'''
brics.info()

# Object dtype can store variables with any or mixed data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   code        5 non-null      object
#  1   country     5 non-null      object
#  2   population  5 non-null      int64
#  3   area        5 non-null      int64
#  4   capital     5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 328.0+ bytes

# %%
#value_counts() function returns object containing counts of unique values. 
#The resulting object will be in descending order so that the first element is the most frequently-occurring element. 
#Excludes NA values by default.

# TO DO: use value_counts() in the brics dataframe to explore the data.
brics = pd.Series(brics)
brics.value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ddd5cd68c67f> in <module>
#       4
#       5 # TO DO: use value_counts() in the brics dataframe to explore the data.
# ----> 6 brics = pd.Series(brics)
#       7 brics.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     229             name = ibase.maybe_extract_name(name, data, type(self))
#     230
# --> 231             if is_empty_data(data) and dtype is None:
#     232                 # gh-17261
#     233                 warnings.warn(
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in is_empty_data(data)
#     594     is_none = data is None
#     595     is_list_like_without_dtype = is_list_like(data) and not hasattr(data, "dtype")
# --> 596     is_simple_empty = is_list_like_without_dtype and not data
#     597     return is_none or is_simple_empty
#     598
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# When the dataset is large and you want to sort the data by ascending or descending order to look at largest or smallest values.

# Ascending order by column code. Uncomment the lines to run them.
# brics.sort_values(by=['code'])   # Ascending by default.
# or
# brics.sort_values(by=['code'], ascending = True)  # No need to mention
# Sorting in ascending order.
brics.sort_values(by=['code'])
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %%
# Sorting in descending order.
brics.sort_values(by=['code'], ascending = False)
# Out:
#   code       country  population      area    capital
# 4   SA  South Africa          55   1221037   Pretoria
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 0   BR        Brazil         200   8515767   Brasilia

# %%
# TO DO: Do you think sorting the data changes the data in original dataframe? 
# print the dataframe and observe the output to get the answer.
brics
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
# No I don't think sorting the data changes the data in original dataframe.
# TO DO: Sort the data to see which country has largest population ( population is in millions).
brics.sort_values(by=['population'],ascending = False)
# From output it is clear that China has largest population
# Out:
#   code       country  population      area    capital
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %%
# TO DO: Sort the data to see which country is smallest in size.
brics.sort_values(by=['area'])
# From below output it is clear that South Africa is smallest in size.
# Out:
#   code       country  population      area    capital
# 4   SA  South Africa          55   1221037   Pretoria
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 3   CH         China        1357   9596961    Beijing
# 1   RU        Russia         144  17098242     Moscow

# %%
# Sorting and printing just one column.

brics.country.sort_values(ascending=False)
# Out:
# 4    South Africa
# 1          Russia
# 2           India
# 3           China
# 0          Brazil
# Name: country, dtype: object

# %%
# TO DO: Sort and print area column on from largest to smallest.

brics.area.sort_values(ascending = False)
# Out:
# 1    17098242
# 3     9596961
# 0     8515767
# 2     3287590
# 4     1221037
# Name: area, dtype: int64

# %%
# Indices can be used to fetch data from a particular row. 
# Example, to fetch data from the 2nd row, we can use index 1 (one)
brics.country[1]

# We will work more on the index column later.
# Out:
# 'Russia'

# %%
# Getting single column from a dataframe

print(brics["country"])
# Out:
# 0          Brazil
# 1          Russia
# 2           India
# 3           China
# 4    South Africa
# Name: country, dtype: object

# %%
# TO DO: Print area column from brics dataframe
print(brics['area'])
# Out:
# 0     8515767
# 1    17098242
# 2     3287590
# 3     9596961
# 4     1221037
# Name: area, dtype: int64

# %%
# Other way to get a single column from a dataframe - use dot

brics.country
# Out:
# 0          Brazil
# 1          Russia
# 2           India
# 3           China
# 4    South Africa
# Name: country, dtype: object

# %%
# TO DO:  Print code column from the dataframe using dot
brics.code
# Out:
# 0    BR
# 1    RU
# 2    IN
# 3    CH
# 4    SA
# Name: code, dtype: object

# %%
# Pritning multiple columns
brics[['country', 'capital']]
# Out:
#         country    capital
# 0        Brazil   Brasilia
# 1        Russia     Moscow
# 2         India  New Delhi
# 3         China    Beijing
# 4  South Africa   Pretoria

# %%
# TO DO: Print country, capital and population

brics[['country','capital','population']]
# Out:
#         country    capital  population
# 0        Brazil   Brasilia         200
# 1        Russia     Moscow         144
# 2         India  New Delhi        1252
# 3         China    Beijing        1357
# 4  South Africa   Pretoria          55

# %%
df = pd.DataFrame({'name': ['Niko', 'Penelope', 'Aria'], 'average score': [10, 5, 3], 'max': [99, 100, 3]})

df['average score']
# Out:
# 0    10
# 1     5
# 2     3
# Name: average score, dtype: int64

# %%
# use col 0 as index. 
# This will remove the 1st column containing the index or sl. no. from the above output, 
# and make the 1st column from actual data as the index.

brics = pd.read_csv(r'C:\Users\dkk\AINE AI - Intern\project-6-Data-Manipulation-and-Visualization\brics.csv',index_col=0)
brics


# Note that the 'code' will be used as Index only and not as a part of data anymore.
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %%
#Adding a new column to the existing Data Frame
brics["on_earth"] = [True, True, True, True, True]    

# We are adding a list here. Read more on lists: https://www.w3schools.com/python/python_lists.asp

brics
# Out:
#            country  population      area    capital  on_earth
# code
# BR          Brazil         200   8515767   Brasilia      True
# RU          Russia         144  17098242     Moscow      True
# IN           India        1252   3287590  New Delhi      True
# CH           China        1357   9596961    Beijing      True
# SA    South Africa          55   1221037   Pretoria      True

# %%
# adding a calculated column
brics["density"] = brics["population"] / brics["area"] * 1000000   # per km sq.
brics
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680

# %%
brics.style.set_precision(2)  # Upto 2 decimal points for all float columns in the dataframe. 

# This WILL NOT change the original dataframe i.e. the original dataframe will still have multiple digits after decimals.
# Out:
# <style  type="text/css" >
# </style><table id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >population</th>        <th class="col_heading level0 col2" >area</th>        <th class="col_heading level0 col3" >capital</th>        <th class="col_heading level0 col4" >on_earth</th>        <th class="col_heading level0 col5" >density</th>    </tr>    <tr>        <th class="index_name level0" >code</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56level0_row0" class="row_heading level0 row0" >BR</th>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row0_col0" class="data row0 col0" >Brazil</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row0_col1" class="data row0 col1" >200</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row0_col2" class="data row0 col2" >8515767</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row0_col3" class="data row0 col3" >Brasilia</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row0_col4" class="data row0 col4" >True</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row0_col5" class="data row0 col5" >23.49</td>
#             </tr>
#             <tr>
#                         <th id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56level0_row1" class="row_heading level0 row1" >RU</th>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row1_col0" class="data row1 col0" >Russia</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row1_col1" class="data row1 col1" >144</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row1_col2" class="data row1 col2" >17098242</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row1_col3" class="data row1 col3" >Moscow</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row1_col4" class="data row1 col4" >True</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row1_col5" class="data row1 col5" >8.42</td>
#             </tr>
#             <tr>
#                         <th id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56level0_row2" class="row_heading level0 row2" >IN</th>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row2_col0" class="data row2 col0" >India</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row2_col1" class="data row2 col1" >1252</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row2_col2" class="data row2 col2" >3287590</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row2_col3" class="data row2 col3" >New Delhi</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row2_col4" class="data row2 col4" >True</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row2_col5" class="data row2 col5" >380.83</td>
#             </tr>
#             <tr>
#                         <th id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56level0_row3" class="row_heading level0 row3" >CH</th>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row3_col0" class="data row3 col0" >China</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row3_col1" class="data row3 col1" >1357</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row3_col2" class="data row3 col2" >9596961</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row3_col3" class="data row3 col3" >Beijing</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row3_col4" class="data row3 col4" >True</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row3_col5" class="data row3 col5" >141.40</td>
#             </tr>
#             <tr>
#                         <th id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56level0_row4" class="row_heading level0 row4" >SA</th>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row4_col0" class="data row4 col0" >South Africa</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row4_col1" class="data row4 col1" >55</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row4_col2" class="data row4 col2" >1221037</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row4_col3" class="data row4 col3" >Pretoria</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row4_col4" class="data row4 col4" >True</td>
#                         <td id="T_1c7b227c_30c3_11ec_9708_8c1645ba6b56row4_col5" class="data row4 col5" >45.04</td>
#             </tr>
#     </tbody></table>

# %%
brics["density"].round(2) # Rounding of individual column to fixed decimal points.
# Out:
# code
# BR     23.49
# RU      8.42
# IN    380.83
# CH    141.40
# SA     45.04
# Name: density, dtype: float64

# %%
# Before starting, let's first print the brics daraframe. Can you please do this?
brics
# Notice that the indices are BR, RU, IN, CH and SA. However, their position (numerical index) are 0, 1, 2, 3 and 4.
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680

# %%
brics.loc["SA"]     # .loc is used with actual value of the index. 
# The value mentioned in the argument must be there in the dataframe's index list.
# Out:
# country       South Africa
# population              55
# area               1221037
# capital           Pretoria
# on_earth              True
# density            45.0437
# Name: SA, dtype: object

# %%
brics.iloc[4]  # .loc is used when we are giving the index reference as number, not the actual value of the index.
# Out:
# country       South Africa
# population              55
# area               1221037
# capital           Pretoria
# on_earth              True
# density            45.0437
# Name: SA, dtype: object

# %%
# TO DO: Use .loc to print the values from all columns for IN
brics.loc['IN']
# Out:
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# on_earth           True
# density         380.826
# Name: IN, dtype: object

# %%
# TO DO: Use .iloc to print the values from all columns from 3rd row (index number will be 1 less than the row number).
brics.iloc[2]
# Out:
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# on_earth           True
# density         380.826
# Name: IN, dtype: object

# %%
#ading a new ROW using append
newrow = {'code':'WK', 'country':'Wakanda', 'population':5,'area':1000000,'capital':'Wakanda City','on_earth':False,'density':5}
brics1 = brics.append(newrow,ignore_index=True)   # Ignoring the existing index.
# Ignoring the existing index will result into new dataframe index 0,1,2,....

'''
Why there is NaN for code in other rows?  
Because the previous 'code' was not a part of datatable. It was an index.
With 'code' in 'newrow', we are adding a new column called 'code'
'''

'''
ignore_index=False will result into error because 'newrow' is a dictionary
and appending a dictionary into a dataframe will not work if we do not ignore the index.
'''
brics1   # append will not result into chaning the actual dataframe. brics will still be the same
# Out:
#         country  population      area       capital  on_earth     density code
# 0        Brazil         200   8515767      Brasilia      True   23.485847  NaN
# 1        Russia         144  17098242        Moscow      True    8.421918  NaN
# 2         India        1252   3287590     New Delhi      True  380.826076  NaN
# 3         China        1357   9596961       Beijing      True  141.398928  NaN
# 4  South Africa          55   1221037      Pretoria      True   45.043680  NaN
# 5       Wakanda           5   1000000  Wakanda City     False    5.000000   WK

# %%
#Adding a new row using .loc
brics.loc['WK'] = ['Wakanda', 5, 1000000, 'Wakanda City', False, 5]   
# Sequence is very important. Data types may get changed due to wrong sequence.
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000

# %%
# TO DO: Add a new row in the dataframe using .loc any other country with some values in all columns.
brics.loc['ENG'] = ['England',1756,5600000,'Londan',True,6]
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# ENG        England        1756   5600000        Londan      True    6.000000

# %%
# Fetching the value in 2-D way. In Excel, we have cells for that, Ex- A2 means column A and row 2.
# All of the below codes will give the same output. Please uncomment and execute them one by one.

brics.loc["IN","capital"]
# Out:
# 'New Delhi'

# %%
brics["capital"].loc["IN"]
# Out:
# 'New Delhi'

# %%
brics.loc["IN"]['capital']
# Out:
# 'New Delhi'

# %%
# Lets create a new dataframe so that brics is not affected.

brics1 = brics
brics1
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# ENG        England        1756   5600000        Londan      True    6.000000

# %%
brics1.drop(['area'], axis=1)  # axis = 0 by default for rows. Axis = 1 for column.

# For multiple columns, mention the columns separated by comma. Ex. df.drop(['name','max'], axis=1)
# Out:
#            country  population       capital  on_earth     density
# code
# BR          Brazil         200      Brasilia      True   23.485847
# RU          Russia         144        Moscow      True    8.421918
# IN           India        1252     New Delhi      True  380.826076
# CH           China        1357       Beijing      True  141.398928
# SA    South Africa          55      Pretoria      True   45.043680
# WK         Wakanda           5  Wakanda City     False    5.000000
# ENG        England        1756        Londan      True    6.000000

# %%
brics1 = brics
# TO DO: Try deleting area and density columns from brics1 dataframe
brics1.drop(['area','density'],axis = 1)
# Out:
#            country  population       capital  on_earth
# code
# BR          Brazil         200      Brasilia      True
# RU          Russia         144        Moscow      True
# IN           India        1252     New Delhi      True
# CH           China        1357       Beijing      True
# SA    South Africa          55      Pretoria      True
# WK         Wakanda           5  Wakanda City     False
# ENG        England        1756        Londan      True

# %%
# TO DO: Delete the record for Wakanda by using its index WK
# Hint: Use WK as identifier and delete axis argument or put axis = 0
brics1=brics
brics1.drop('WK',axis=0)
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680
# ENG        England        1756   5600000     Londan      True    6.000000

# %%
brics1 = brics

# Another way to drop columns
brics1.drop(columns=['area', 'density'])
# Out:
#            country  population       capital  on_earth
# code
# BR          Brazil         200      Brasilia      True
# RU          Russia         144        Moscow      True
# IN           India        1252     New Delhi      True
# CH           China        1357       Beijing      True
# SA    South Africa          55      Pretoria      True
# WK         Wakanda           5  Wakanda City     False
# ENG        England        1756        Londan      True

# %%
brics1 = brics

# Drop rows by index

brics1.drop(['IN', 'CH'])
# Out:
#            country  population      area       capital  on_earth    density
# code
# BR          Brazil         200   8515767      Brasilia      True  23.485847
# RU          Russia         144  17098242        Moscow      True   8.421918
# SA    South Africa          55   1221037      Pretoria      True  45.043680
# WK         Wakanda           5   1000000  Wakanda City     False   5.000000
# ENG        England        1756   5600000        Londan      True   6.000000

# %%
# The shape function helps us to find the shape or size of an array or matrix. In Excel - A1:D10.  
# shape[0] means we are working along the first dimension of your array.
# If Y has n rows and m columns, then Y.shape is (n,m). So Y.shape[0] is n.

for index in range(brics.shape[0]):    
    countryName = brics.iloc[index,0]  # row - index, column - 0
    cityName = brics.iloc[index, 3]  # row - index, column - 3
    print('The Capital City of', countryName, 'is', cityName)
# Out:
# The Capital City of Brazil is Brasilia
# The Capital City of Russia is Moscow
# The Capital City of India is New Delhi
# The Capital City of China is Beijing
# The Capital City of South Africa is Pretoria
# The Capital City of Wakanda is Wakanda City
# The Capital City of England is Londan

# %%
#Another solution
for index in range(brics.shape[0]):
    print('The Capital City of', brics.iloc[index, 0], 'is', brics.iloc[index, 3])
# Out:
# The Capital City of Brazil is Brasilia
# The Capital City of Russia is Moscow
# The Capital City of India is New Delhi
# The Capital City of China is Beijing
# The Capital City of South Africa is Pretoria
# The Capital City of Wakanda is Wakanda City
# The Capital City of England is Londan

# %%
#Another solution
# iterrows() is a generator that iterates over the rows of the dataframe and returns the index of each row, 
# in addition to an object containing the row itself.

for index, row in brics.iterrows():
    print("The Capital City of",row['country'],"is", row['capital'])
# Out:
# The Capital City of Brazil is Brasilia
# The Capital City of Russia is Moscow
# The Capital City of India is New Delhi
# The Capital City of China is Beijing
# The Capital City of South Africa is Pretoria
# The Capital City of Wakanda is Wakanda City
# The Capital City of England is Londan

# %%
cars = pd.read_csv(r'C:\Users\dkk\AINE AI - Intern\project-6-Data-Manipulation-and-Visualization\cars.csv')

# Print top 5 rows from the data, without any sorting or filter.
cars.head()
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True

# %%
# TO DO: Print top 7 rows from the data
# To print n number of rows, enter the value of n in the head() as an argument.

cars.head(7)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
# For bottom 5 rows in the dataframe
cars.tail(5)
# Out:
#   Unnamed: 0  cars_per_cap  country  drives_right
# 2        JAP           588    Japan         False
# 3         IN            18    India         False
# 4         RU           200   Russia          True
# 5        MOR            70  Morocco          True
# 6         EG            45    Egypt          True

# %%
# TO DO: Print last 10 rows from the dataframe
cars.tail(10)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
# Giving a name to the unnamed column

print(cars)

df1 = cars.rename( columns={'Unnamed: 0':'code'}, inplace=False ) 
cars.rename( columns={'Unnamed: 0':'code'}, inplace=True ) 

print(df1)
print(cars)      # With False, there will be no change in cars dataframe.



'''
inplace = True has been used to overwrite the existing dataframe. The default is False, if nothing mentioned.
When inplace = True , the data is modified in place, which means it will return nothing 
and the dataframe is now updated. 
When inplace = False , which is the default, 
then the operation is performed and it returns a copy of the object. You then need to save it to something.'''
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True
# '\ninplace = True has been used to overwrite the existing dataframe. The default is False, if nothing mentioned.\nWhen inplace = True , the data is modified in place, which means it will return nothing \nand the dataframe is now updated. \nWhen inplace = False , which is the default, \nthen the operation is performed and it returns a copy of the object. You then need to save it to something.'

# %%
print(cars['cars_per_cap'])  # without column name at the top. Prints data and detail
# Out:
# 0    809
# 1    731
# 2    588
# 3     18
# 4    200
# 5     70
# 6     45
# Name: cars_per_cap, dtype: int64

# %%
print(cars[['cars_per_cap']])  # print the actual data
# Out:
#    cars_per_cap
# 0           809
# 1           731
# 2           588
# 3            18
# 4           200
# 5            70
# 6            45

# %%
# TO DO: Read the data again and set the 1st column as the index column. Then, print the cars dataframe.
cars = pd.read_csv(r'C:\Users\dkk\AINE AI - Intern\project-6-Data-Manipulation-and-Visualization\cars.csv',index_col=0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# TO DO : Print the details of RU
# Hint: You should use either .loc or .iloc (just one is correct).
cars.loc['RU']
# Out:
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object

# %%
# TO DO: Can you change the above answer to show the column name at the top? 
# Hint: Recap last 3-4 code cells.
cars.loc[['RU']]
# Out:
#     cars_per_cap country  drives_right
# RU           200  Russia          True

# %%
# TO DO: Print all details for RU and AUS from cars dataframe.
cars.loc[['RU','AUS']]
# Out:
#      cars_per_cap    country  drives_right
# RU            200     Russia          True
# AUS           731  Australia         False

# %%
# Print the Cars Per Capita (cars_per_cap) for India (IN).
cars.loc['IN']['cars_per_cap']
# Out:
# 18

# %%
# Print the Cars Per Capita (cars_per_cap) for India (IN) and Russia (RU).
cars.loc[['IN','RU']]['cars_per_cap']
# Out:
# IN     18
# RU    200
# Name: cars_per_cap, dtype: int64

# %%
# Print the Cars Per Capita and Country name for India and Russia
cars.loc[['IN','RU']][['cars_per_cap','country']]
# Out:
#     cars_per_cap country
# IN            18   India
# RU           200  Russia

# %%
# If working on Jupyter Notebook and data is in local drive
marks = pd.read_csv(r'C:\Users\dkk\AINE AI - Intern\project-6-Data-Manipulation-and-Visualization\marks.csv')
marks
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
# TO DO: Show the shape of the dataframe
# Hint: shape()
marks.shape
# Out:
# (20, 7)

# %%
# TO DO: Get the information and structure of the data with non-null value counts
marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      20 non-null     object
#  1   Student_Name    20 non-null     object
#  2   English         20 non-null     float64
#  3   Maths           20 non-null     float64
#  4   Science         20 non-null     float64
#  5   History         20 non-null     float64
#  6   Social_Studies  20 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 1.2+ KB

# %%
# Print datatypes of the each column
print(type(marks.Student_ID))
print(type(marks.Student_Name))
print(type(marks.English))
print(type(marks.Maths))
print(type(marks.Science))
print(type(marks.History))
print(type(marks.Social_Studies))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
print(type(marks))
print(type(marks.English))  # Column's dtype is Series, the dtype of the values is Object.
print(type(5))
print(type(5.5))
print(type("Python"))
print(type(True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# Run these lines one by one and observe the difference in the three outputs.
print(marks)
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
display(marks)
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
marks
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
num = 5 # Assignment. No output of assignment operator. 
num

num == 6 # Comparison/equality. Output is either True or False
# Out:
# False

# %%
# selecting marks for 'Ria'
display(marks.loc[(marks.Student_Name == 'Ria')])  # in case the index is not known for large datasets
# Out:
#    Student_ID Student_Name    English      Maths   Science    History  \
# 17        S18          Ria  30.830802  25.545682  84.27165  78.727155
#
#     Social_Studies
# 17         7.30567

# %%
# TO DO: Print all records for David
display(marks.loc[(marks.Student_Name == 'David')])
# Out:
#   Student_ID Student_Name    English      Maths    Science    History  \
# 3        S04        David  21.160844  95.052971  35.860852  62.865185
#
#    Social_Studies
# 3       95.264572

# %%
# Using OR operator to print details if the name is either 'Ria' OR 'David'
display(marks.loc[(marks.Student_Name == 'Ria') | (marks.Student_Name == 'David')])
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
#
#     Social_Studies
# 3        95.264572
# 17        7.305670

# %%
# TO DO: Print all records is the Student IS is either S05 or S10
display(marks.loc[(marks.Student_ID == 'S05') | (marks.Student_ID == 'S10')])
# Out:
#   Student_ID Student_Name    English      Maths   Science    History  \
# 4        S05       Edward  63.250994  60.693247  7.020915  60.505272
# 9        S10         John  30.968731  14.282925  3.312853  79.916094
#
#    Social_Studies
# 4       34.041671
# 9       32.706891

# %%
# TO DO: Fetch all details where marks in English > 70 or marks in Maths > 70.
display(marks.loc[(marks.English > 70) | (marks.Maths>70)])
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 3        95.264572
# 5        85.019761
# 8        90.483635
# 11       71.930382
# 13       20.583259
# 15       74.528425
# 16        8.432155
# 18       83.344403

# %%
# Using AND operator to combine two conditions. 

# TO DO: Fetch all details where marks in English > 70 AND marks in Maths > 70.
# Hint: Use & for AND
display(marks.loc[(marks.English > 70) & (marks.Maths>70)])
# Out:
#    Student_ID Student_Name    English      Maths   Science    History  \
# 18        S19        Suvin  72.218179  85.284128  32.55506  47.007177
#
#     Social_Studies
# 18       83.344403

# %%
# Using NOT function 

# TO DO: Fetch all details for all students except for Ria or the all students who are not Ria.
# Hint: Use != for 'not equal to'
display(marks.loc[(marks.Student_Name != 'Ria')])
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 18       83.344403
# 19       82.802787

# %%
# Index column can be changed by giving the name of the column - unique and case-sensitive
marks = pd.read_csv(r'C:\Users\dkk\AINE AI - Intern\project-6-Data-Manipulation-and-Visualization\marks.csv',index_col = 'Student_ID')  # could have given the index no. of the columns (0,1..) as well.
display(marks)
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S13               Maria   8.215446  25.042783  16.518147  36.543154
# S14                Noel  72.833673   7.160086  22.089014  52.867757
# S15              Oliver   5.982402  16.460926  40.977224  80.925749
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891
# S11              34.449110
# S12              71.930382
# S13              80.665074
# S14              20.583259
# S15              83.312063
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.loc[1:10]) # Range of values. Includes all values/labels.

# .loc is different than .iloc
# .loc is label-based. We need to SPECIFY the VALUE of the index. The values must be there in the index column.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-f1b974fbf958> in <module>
# ----> 1 display(marks.loc[1:10]) # Range of values. Includes all values/labels.
#       2
#       3 # .loc is different than .iloc
#       4 # .loc is label-based. We need to SPECIFY the VALUE of the index. The values must be there in the index column.
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1086         if isinstance(key, slice):
#    1087             self._validate_key(key, axis)
# -> 1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
#    1090             return self._getbool_axis(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1120
#    1121         labels = obj._get_axis(axis)
# -> 1122         indexer = labels.slice_indexer(
#    1123             slice_obj.start, slice_obj.stop, slice_obj.step, kind="loc"
#    1124         )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    4964         slice(1, 3, None)
#    4965         """
# -> 4966         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    4967
#    4968         # return a slice
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5165         start_slice = None
#    5166         if start is not None:
# -> 5167             start_slice = self.get_slice_bound(start, "left", kind)
#    5168         if start_slice is None:
#    5169             start_slice = 0
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5077         # For datetime indices label may be a string that has to be converted
#    5078         # to datetime boundary according to its resolution.
# -> 5079         label = self._maybe_cast_slice_bound(label, side, kind)
#    5080
#    5081         # we need to look up the label
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    5029         # this is rejected (generally .loc gets you here)
#    5030         elif is_integer(label):
# -> 5031             self._invalid_indexer("slice", label)
#    5032
#    5033         return label
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3265         Consistent invalid indexer message.
#    3266         """
# -> 3267         raise TypeError(
#    3268             f"cannot do {form} indexing on {type(self).__name__} with these "
#    3269             f"indexers [{key}] of type {type(key).__name__}"
#
# TypeError: cannot do slice indexing on Index with these indexers [1] of type int

# %%
'''
iloc is integer index-based. 
So here, we have to specify rows and columns by their integer index.
'''
display(marks.iloc[0:10]) # IMPORTANT - Out of 11 indices, the last one will be excluded.

# Returns output of the indices without matching the value of incides entered and the value in the column.
# iloc will not work if the indices are not integers.
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891

# %%
# What will be the output here? First think of the answer and then run the code.

display(marks.iloc['S04'])

# What is the issue?
#Ans - iloc is the integer index base, hence cannot index by location index with a non-integer key
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-e920fc5c358e> in <module>
#       1 # What will be the output here? First think of the answer and then run the code.
#       2
# ----> 3 display(marks.iloc['S04'])
#       4
#       5 # What is the issue?
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1491             key = item_from_zerodim(key)
#    1492             if not is_integer(key):
# -> 1493                 raise TypeError("Cannot index by location index with a non-integer key")
#    1494
#    1495             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
# Correct the issue of the previous code cell and write the correct syntax here.
display(marks.loc['S04'])
# Out:
# Student_Name        David
# English           21.1608
# Maths              95.053
# Science           35.8609
# History           62.8652
# Social_Studies    95.2646
# Name: S04, dtype: object

# %%
# Data of multiple and non-consecuitive indices
# Selecting details of the 1st and 5th row
display(marks.iloc[[0, 4]])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S05              34.041671

# %%
# TO DO: Print the details from 0th, 5th and 8th rows, along with the details of indices 4th, 11th and 16th.
display(marks.iloc[[0,4,8,3,10,15]])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S04               David  21.160844  95.052971  35.860852  62.865185
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S16               Peter  40.694327  91.395888   8.149884  13.852098
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S05              34.041671
# S09              90.483635
# S04              95.264572
# S11              34.449110
# S16              74.528425

# %%
# .loc can be used to fetch details from a range of index values in a sequence.

display(marks.loc['S01':'S05'])   # Continuous series of the indices based on label.
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
# Run these line one by one and observe the output to notice the difference and execution of the syntax
display(marks.iloc[2:5])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[0:5])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[:5])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[15:20])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[15:])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[15:100])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[:])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S13               Maria   8.215446  25.042783  16.518147  36.543154
# S14                Noel  72.833673   7.160086  22.089014  52.867757
# S15              Oliver   5.982402  16.460926  40.977224  80.925749
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891
# S11              34.449110
# S12              71.930382
# S13              80.665074
# S14              20.583259
# S15              83.312063
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
# TO DO: Copy paste the above codes and explain the output for each syntax as comments as per given example.
# Example: display(marks.iloc[[3:5]])  # Prints all values from all columns for indices 2, 3 and 4.
# display(marks.iloc[2:5]) prints all values from all columns for indices 0,1,2,3 and 4.
# display(marks.iloc[0:5]) prints all values from all columns for indices from 0 to 4.
# display(marks.iloc[:5])   prints all values from all columns for indices from 0 to 4.
# display(marks.iloc[15:20])  prints all values from all columns for indices from 14 to 19.
# display(marks.iloc[15:]) prints all values from all columns for indices from 14 to end.
# display(marks.iloc[15:100]) prints all values from all columns for indices from 14 to 99.
# display(marks.iloc[:])  prints all values from all columns for indices from start to end.
#.................... Data cleaning : Empty value treatment iin dataframes

temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],  # With strings, it will become 'None'
          "temperature_f":[67.24,84.56,91.61,None,49.64]   #With numbers, it will become 'NaN'
         })
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %%
# To identify the null value. Return true if the value is null otherwise false
temps.isna()
# Out:
#    sequence  measurement_type  temperature_f
# 0     False             False          False
# 1     False             False          False
# 2     False             False          False
# 3     False              True           True
# 4     False             False          False

# %%
# Return the count of missing value from each column     
temps.isna().sum()
# Out:
# sequence            0
# measurement_type    1
# temperature_f       1
# dtype: int64

# %%
# Total count of null from all columns
temps.isna().sum().sum()
# Out:
# 2

# %%
# Drop/delete the row containing missing values

clean_temps = temps.dropna(how='any')  # how: {'any', 'all'}. Default 'any'
display (clean_temps)

# ‘any’ : If any NA values are present, drop that row or column.
# ‘all’ : If all values are NA, drop that row or column.


# Observe, in the output, index 3 is not there.
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %%
# TO DO:  Copy paste the codes from the above cell, change the 'how' argument as 'all' and observe the difference in output.
clean_temps = temps.dropna(how='all') 
display (clean_temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %%
# Drop the ROWS where at least one element is missing.
temps.dropna()
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %%
# Drop COLUMNS where there are missing values.

# Drop the columns where at least one element is missing.
temps.dropna(axis = 'columns') # Without the 'axis' argument, rows will be dropped by default as you did in the previous code.
# Out:
#    sequence
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
temps['temperature_f'].cumsum()   # Returns the commulative sum. 

# It will skip null values. skipna = TRUE by default

# CAN YOU THINK OF ANY PRACTICAL USE OF cumsum() ?
# Ans - used to calculate the cumulative sum of the vector.
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4    293.05
# Name: temperature_f, dtype: float64

# %%
temps['temperature_f'].cumsum(skipna=False)
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4       NaN
# Name: temperature_f, dtype: float64

# %%
# fill missing value with zero
temps.fillna(value=0, inplace = True)   # Do you remember the use of inplace? If not, please scroll up and check.
display(temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4                0           0.00
# 4         5        estimated          49.64

# %%
# Print the dataframe

temps

# Why 0 in last column is 0.00 while only 0 in measurement_type? Please explain as a comment in this cell.
# Ans = Data type of measurement_type column is 'str' and data type of column temperature_f is 'float', hence 0 in last column 
# is 0.00 while only 0 in measurement_type.
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4                0           0.00
# 4         5        estimated          49.64

# %%
# fill missing value with previous value
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps.fillna(method='pad' , inplace=True)  # 'pad' means padding. Take value from previous row
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4           actual          91.61
# 4         5        estimated          49.64

# %%
# fill missing value with next value
temps1 = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps1.fillna(method='bfill' , inplace=True)  # bfill takes next value to replace
temps1
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4        estimated          49.64
# 4         5        estimated          49.64

# %%
# fill missing value with mean
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps['temperature_f'].fillna(temps['temperature_f'].mean(), inplace=True)  # Mean will not work on strings
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual        67.2400
# 1         2           actual        84.5600
# 2         3           actual        91.6100
# 3         4             None        73.2625
# 4         5        estimated        49.6400

# %%
# lambda is used to define a temporary expression without any return statement. It always contains an expression
# that is returned. There is no need to assign a variable with lambda.


def cube(y):
    return y*y*y  # return is a keyword. Python stops when the code reaches to return statement. Print is a function.
    

# using the normally defined function
    print(cube(5))
 
# using the lambda function    # Why this is red? How to resolve it?
# Ans - Above line is red due to indentation and it can be resolve by select the above line and press "Tab" 
lambda_cube = lambda y: y*y*y
print(lambda_cube(5))
# Out:
# 125

# %%
# Creating new dataframe to explore the use of Lambda and changing indices.

teams = pd.DataFrame({"Region":['North','West','East','South'],
          "Team":['One','Two','One','Two'],
          "Squad":['A','B','C','D'],
          "Revenue":[7500,5500,2750,6400],
            "Cost":[5200,5100,4400,5300]})

display (teams)
# Out:
#   Region Team Squad  Revenue  Cost
# 0  North  One     A     7500  5200
# 1   West  Two     B     5500  5100
# 2   East  One     C     2750  4400
# 3  South  Two     D     6400  5300

# %%
# apply() to alter values along an axis in your dataframe or in a series/column 

# Categorise based on the revenue and cost
teams['Profit'] = teams.apply(lambda x: 'Profit' if x['Revenue']>x['Cost'] else 'Loss',axis=1)
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit
# 0  North  One     A     7500  5200  Profit
# 1   West  Two     B     5500  5100  Profit
# 2   East  One     C     2750  4400    Loss
# 3  South  Two     D     6400  5300  Profit

# %%
# Use map() to substitute each value in a series
team_map = {"One":"Red","Two":"Blue"}      # new variable - dictionary (key-value pair)
teams['Team Color'] = teams['Team'].map(team_map) # A new column with mapped values
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue

# %%
# applymap() method do elementwise operation on the entire dataframe.
# This method applies a function that accepts and returns a scalar to every element of a DataFrame.

teams.applymap(lambda x: len(str(x)))  # int(x) won't work because data has strings which can not be convereted to int.
# Out:
#    Region  Team  Squad  Revenue  Cost  Profit  Team Color
# 0       5     3      1        4     4       6           3
# 1       4     3      1        4     4       6           4
# 2       4     3      1        4     4       4           3
# 3       5     3      1        4     4       6           4

# %%
# Grouping on different categories. Needs the category as well as parameter
teams.groupby(['Profit']).max()
# Out:
#        Region Team Squad  Revenue  Cost Team Color
# Profit
# Loss     East  One     C     2750  4400        Red
# Profit   West  Two     D     7500  5300        Red

# %%
# TO DO: Can you group the records on Cost with minimum values?
teams.groupby(['Cost']).min()
# Out:
#      Region Team Squad  Revenue  Profit Team Color
# Cost
# 4400   East  One     C     2750    Loss        Red
# 5100   West  Two     B     5500  Profit       Blue
# 5200  North  One     A     7500  Profit        Red
# 5300  South  Two     D     6400  Profit       Blue

# %%
# TO DO: Can you group the records on Revenue column with mean values?
teams.groupby(['Revenue']).mean()
# Out:
#          Cost
# Revenue
# 2750     4400
# 5500     5100
# 6400     5300
# 7500     5200

# %%
# Grouping on the basis of aggregates
teams.groupby(['Team']).agg({'Revenue':['mean','min','max']})
# Out:
#      Revenue
#         mean   min   max
# Team
# One     5125  2750  7500
# Two     5950  5500  6400

# %%
# TO DO: Copy-paste the copy from earlier to redefine teams dataframe, and display it
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue

# %%
# Setting two columns as index when a single column has not unique values.

teams_reindex = teams.set_index(['Region','Team'])  # 2 indices. useful when values are not unique
display(teams)

print()    # TO print blank/new line.


display(teams_reindex)
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue
#             Squad  Revenue  Cost  Profit Team Color
# Region Team
# North  One      A     7500  5200  Profit        Red
# West   Two      B     5500  5100  Profit       Blue
# East   One      C     2750  4400    Loss        Red
# South  Two      D     6400  5300  Profit       Blue

# %%
# Restructuring the dataframe based the multiple indices
stacked = pd.DataFrame(teams_reindex.stack())
stacked
# Out:
#                              0
# Region Team
# North  One  Squad            A
#             Revenue       7500
#             Cost          5200
#             Profit      Profit
#             Team Color     Red
# West   Two  Squad            B
#             Revenue       5500
#             Cost          5100
#             Profit      Profit
#             Team Color    Blue
# East   One  Squad            C
#             Revenue       2750
#             Cost          4400
#             Profit        Loss
#             Team Color     Red
# South  Two  Squad            D
#             Revenue       6400
#             Cost          5300
#             Profit      Profit
#             Team Color    Blue

# %%
# Mergining dataframes
# We are going to learn how to merge multiple dataframes based on left, right and inner join.

# Defining two new dataframes
group1 = pd.DataFrame({'name': ['Alice', 'Bob', 'Charlie', 'David'],
                    'number': [1, 2, 3, 4]})
group2 = pd.DataFrame({'name': ['Charlie', 'David', 'Edward', 'Ford'],
                    'number': [3, 4, 5, 6]})

group1.merge(group2,how='left', on='number')   # Left - all from 1st table and only common from 2nd table.

# Notice the NAN or empty values.
# Out:
#     name_x  number   name_y
# 0    Alice       1      NaN
# 1      Bob       2      NaN
# 2  Charlie       3  Charlie
# 3    David       4    David

# %%
group1.merge(group2)   # Shows only the common records.
# Out:
#       name  number
# 0  Charlie       3
# 1    David       4

# %%
group1.merge(group2,how='inner',left_on='number',right_on='number')  # Inner - Shows only the common records

# Why there are no null values now in the output? Answer as a comment.
# There are no null values in output because inner join shows only common records.
# Out:
#     name_x  number   name_y
# 0  Charlie       3  Charlie
# 1    David       4    David

# %%
group1.merge(group2,how='right',left_on='number',right_on='number')  # Right - All from 2nd table, common from 1st table.
# Out:
#     name_x  number   name_y
# 0  Charlie       3  Charlie
# 1    David       4    David
# 2      NaN       5   Edward
# 3      NaN       6     Ford

# %%
# TO DO : Read the instructions and write the codes.
'''
Get the data

Open mtcars.csv in Excel or Text dataset and have a look at the data. Understand the variables.

You can also open in Google drive to view it however, make sure you download it in your local system and upload in 
Jupyter Notebook folder where you have the Python file.
'''
mtcars = pd.read_csv(r'C:\Users\dkk\AINE AI - Intern\project-6-Data-Manipulation-and-Visualization\mtcars.csv')
mtcars
# Out:
#               car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
# TO DO: 
# Import pandas package as pd
import pandas as pd
# Use function pd.read_csv to upload mtcars.csv by using either of two methods below:
    # Use_cols ( all the columns except car_names )
    # Index_col = car_names ( expected output as below)
mtcars = pd.read_csv(r'C:\Users\dkk\AINE AI - Intern\project-6-Data-Manipulation-and-Visualization\mtcars.csv', index_col = 'car_names')
mtcars
# display the dataframe
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# car_names
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb
# car_names
# Mazda RX4               4
# Mazda RX4 Wag           4
# Datsun 710              1
# Hornet 4 Drive          1
# Hornet Sportabout       2
# Valiant                 1
# Duster 360              4
# Merc 240D               2
# Merc 230                2
# Merc 280                4
# Merc 280C               4
# Merc 450SE              3
# Merc 450SL              3
# Merc 450SLC             3
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4
# Fiat 128                1
# Honda Civic             2
# Toyota Corolla          1
# Toyota Corona           1
# Dodge Challenger        2
# AMC Javelin             2
# Camaro Z28              4
# Pontiac Firebird        2
# Fiat X1-9               1
# Porsche 914-2           2
# Lotus Europa            2
# Ford Pantera L          4
# Ferrari Dino            6
# Maserati Bora           8
# Volvo 142E              2

# %%
# Import he required package 
import matplotlib.pyplot as plt

# TO DO : Create a scatter plot with mpg and hp by providing xlabel and ylabel
plt.scatter(mtcars.mpg,mtcars.hp)
plt.xlabel('mpg')
plt.ylabel('hp')
plt.title('Scatter Plot mpg VS hp')
plt.show()

# %%
# TO DO: Change the color to red in the previous code
plt.scatter(mtcars.mpg,mtcars.hp,color = 'red')
plt.xlabel('mpg')
plt.ylabel('hp')
plt.title('Scatter Plot mpg VS hp')
plt.show()

# %%
# TO DO: Create crosstab for cyl(cylinder) and columns as count

# A cross-tabulation (or crosstab) is a two- (or more) dimensional table that records the number (frequency) of 
# respondents that have the specific characteristics described in the cells of the table.
pd.crosstab(mtcars.cyl,mtcars.cyl.count())
# Out:
# col_0  32
# cyl
# 4      11
# 6       7
# 8      14

# %%
# Other way to create the crosstab
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ct = pd.crosstab(mtcars.cyl, mtcars.cyl)

ct.plot.bar(stacked=True)    # Try staked=False and then by removing stakced part
plt.legend(title='mark')   # Optional

plt.show()

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ct = pd.crosstab(mtcars.cyl, mtcars.cyl)

ct.plot.bar(stacked=False)    # Try staked=False and then by removing stakced part
plt.legend(title='mark')   # Optional

plt.show()

# %%
# TO DO: Create crosstab for cyl(cylinder) and am as 'ct2' and create a bar plot

# Reading reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html
pd.crosstab(mtcars.cyl,mtcars.am)
# Out:
# am    0  1
# cyl
# 4     3  8
# 6     4  3
# 8    12  2

# %%
ct = pd.crosstab(mtcars.cyl, mtcars.am)

ct.plot.bar(stacked=False)    # Try staked=False and then by removing stakced part
plt.legend(title='mark')   # Optional

plt.show()

# %%
# TO DO: Create groupby (cyl) to visualize mpg and hp in a bar chart
# Hint: Use nunique() 
ct1 = mtcars.groupby(['cyl'])
plt.bar(mtcars.mpg,mtcars.hp,color='blue')
plt.xlabel('mpg')
plt.ylabel('hp')
plt.show()

# %%
# TO DO: Create a Histogram for MPG column
# Reading: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.hist.html
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(mtcars.mpg)
plt.show()
